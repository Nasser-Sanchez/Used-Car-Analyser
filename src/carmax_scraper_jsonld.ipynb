# %% [markdown]
# # CarMax USA Scraper - JSON-LD Edition
#
# **Based on:** `Carmax USA.R` - same Selenium scroll-to-load flow, but extracts structured JSON-LD instead of fragile CSS selectors.
#
# Run cells top-to-bottom. Each major step is a separate cell.
